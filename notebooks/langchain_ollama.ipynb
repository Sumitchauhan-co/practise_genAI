# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="minimax-m3:cloud")

# %%
res = llm.invoke("Hey there!")
res.content
# Out:
# "Hey! 👋 How's it going? What can I help you with today?"
